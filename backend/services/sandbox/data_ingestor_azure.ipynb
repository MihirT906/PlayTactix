# %%
# imports
import pandas as pd
import requests
import numpy as np
import json

from data_ingestor_github import SkillCornerDataIngestor
di = SkillCornerDataIngestor()

# %%
# To load all the data
match_id = 1886347
data = di.load_data(match_id=match_id)
# Out:
# /Users/mihirthalanki/Documents/MT/Hackathon/PlayTactix/backend/services/data_ingestor_github.py:269: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   silver_event_data['event_subtype_id'] = silver_event_data['event_subtype_id'].fillna(0).astype(int)
# /Users/mihirthalanki/Documents/MT/Hackathon/PlayTactix/backend/services/data_ingestor_github.py:270: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   silver_event_data['event_subtype'] = silver_event_data['event_subtype'].fillna('Unknown')
# ...

# %%
from azure.identity import DefaultAzureCredential
from azure.storage.blob import BlobServiceClient

import json

# %%
try:
    account_url = "https://playtactixstorage.blob.core.windows.net"
    container_name = "skillcorner-data"
    blob_name = f"matches/{match_id}/gold_data.json"
    default_credential = DefaultAzureCredential()

    # Create the BlobServiceClient object
    blob_service_client = BlobServiceClient(account_url, credential=default_credential)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    
    blob_client.upload_blob(json.dumps(data), overwrite=False)
    print(f"Blob '{blob_name}' uploaded successfully to container '{container_name}'.")
    
except Exception as ex:
    print('Exception:')
    print(ex)
# Out:
# Exception:
# The specified blob already exists.
# RequestId:fe1f05a4-f01e-00a3-529e-e84c0f000000
# Time:2026-05-20T21:23:13.9684687Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:fe1f05a4-f01e-00a3-529e-e84c0f000000
# Time:2026-05-20T21:23:13.9684687Z</Message></Error>

# %%
try:
    account_url = "https://playtactixstorage.blob.core.windows.net"
    container_name = "skillcorner-data"
    blob_name = f"matches/{match_id}/gold_data.json"
    default_credential = DefaultAzureCredential()

    # Create the BlobServiceClient object
    blob_service_client = BlobServiceClient(account_url, credential=default_credential)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    
    downloaded_blob = blob_client.download_blob()
    blob_text = downloaded_blob.readall().decode("utf-8")
    data = json.loads(blob_text)
    print(f"Blob '{blob_name}' downloaded successfully from container '{container_name}'.")
    print(type(data))
    
except Exception as ex:
    print('Exception:')
    print(ex)
# Out:
# Blob 'matches/1886347/gold_data.json' downloaded successfully from container 'skillcorner-data'.
# <class 'dict'>

# %%
data['10']
# Out:
# {'period': 1.0,
#  'players': {'x': [-39.63,
#    -19.21,
#    -21.83,
#    -1.16,
#    -18.88,
#    -7.41,
#    -9.51,
#    -2.5,
#    -0.78,
#    -1.85,
#    1.27,
#    40.47,
#    17.85,
#    16.78,
#    17.03,
#    17.55,
#    11.7,
#    10.16,
#    0.91,
#    7.74,
#    0.4,
#    2.67],
#   'y': [-0.08,
#    -9.18,
#    0.47,
#    -32.47,
#    15.73,
#    7.13,
#    -5.01,
#    7.27,
#    -20.69,
#    18.8,
#    0.88,
#    0.24,
#    5.52,
#    -3.67,
#    14.69,
#    -13.6,
#    6.73,
#    -2.12,
#    18.96,
#    -16.27,
#    -8.28,
#    9.94],
#   'player_id': [51009,
#    176224,
#    51649,
#    50983,
#    735578,
#    50978,
#    735574,
#    795507,
#    795505,
#    735573,
#    966120,
#    285188,
#    51667,
#    33697,
#    51713,
#    133498,
#    14736,
#    23418,
#    133501,
#    965685,
#    50951,
#    38673],
#   'id': [51009,
#    176224,
#    51649,
#    50983,
#    735578,
#    50978,
#    735574,
#    795507,
#    795505,
#    735573,
#    966120,
# ...
