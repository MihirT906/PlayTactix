# %%
# from data_pipeline import DataPipeline

# %%
from data_loader import DataLoader
from data_preprocessor import DataPreprocessor


class DataPipeline:
    def __init__(self):
        self.data_loader = DataLoader()
        self.data_preprocessor = DataPreprocessor()

    def get_processed_data(self, match_id):
        enriched_data = self.data_loader.create_enriched_tracking_data(match_id)
        events_data = self.data_loader.load_event_data(match_id)
        frame_events = self.data_preprocessor.precompute_event_associations(events_data)
        
        return enriched_data, frame_events

# %%
dp = DataPipeline()
match_id = 1886347

# %%
tracking_data, frame_events = dp.get_processed_data(match_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tracking_data, frame_events = dp.get_processed_data(match_id)
#
# Cell In[8], line 12, in DataPipeline.get_processed_data(self, match_id)
#      10 def get_processed_data(self, match_id):
#      11     enriched_data = self.data_loader.create_enriched_tracking_data(match_id)
# ---> 12     frame_events = self.data_preprocessor.precompute_event_associations(enriched_data)
#      13     return enriched_data, frame_events
#
# File ~/Documents/MT/Hackathon/PlayTactix/backend/services/data_preprocessor.py:26, in DataPreprocessor.precompute_event_associations(self, events_data)
#      16 frame_events = defaultdict(
#      17     lambda: {
#      18         "player_possession": [],
#    (...)     22     }
#      23 )
#      25 # Group events by type for efficient processing
# ...
