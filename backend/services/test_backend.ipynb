# %%
from frame_data_service import FrameDataService
fds = FrameDataService()
frames = fds.get_frames(match_id=1886347, start=150, end=200)
# Out:
# /Users/mihirthalanki/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/features/pitch_control.py:324: RuntimeWarning: invalid value encountered in divide
#   influence_values = influence_values / np.max(influence_values)

# %%
frames['frames'][186]['overlays']
# Out:
# {'pitch_control': {'type': 'pitch_control',
#   'data': [[nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
#     nan,
# ...

# %%
len(frames['frames'][100]['overlays']['pitch_control']['data'])

# %%
# import pandas as pd
# tracking_df = pd.read_parquet("../../data/silver_tracking_data_kloppy.parquet")
# tracking_df.head(40)

# %%
# match meta endpoint
import requests

start = 10  # change as needed
end = 20  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/match_meta?match_id={match_id}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)

# %%
# match data endpoint
import requests

start = 10  # change as needed
end = 100  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/match/{match_id}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)

# %%
# fetch chunk endpoint
import requests

start = 185  # change as needed
end = 187  # change as needed
match_id = 1899585  # change as needed
url = f"http://localhost:8000/data/frames?match_id={match_id}&start={start}&end={end}"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'requested_match_id': 1899585, 'requested_start': 185, 'requested_end': 187, 'frames': {'185': {'period': None, 'players': {'x': [], 'y': [], 'player_id': [], 'team': [], 'vx': [], 'vy': [], 'speed': []}, 'ball': {'ball_x': None, 'ball_y': None, 'ball_z': None}, 'events': [], 'overlays': {}}, '186': {'period': 1, 'players': {'x': [-7.0, 14.55, 1.4, 2.32, 17.01, 26.89, 23.09, 13.57, 8.87, -37.03, -9.08, -8.75, 2.46, -4.03, -9.34, 6.14, 14.01, 15.54, 10.54, 17.56, 41.54], 'y': [12.66, 23.94, 10.83, 10.49, -16.36, -2.6, 13.53, 13.94, 20.8, 0.81, -1.19, 18.05, 0.74, -10.57, 8.01, 29.09, 4.19, 11.36, -7.32, 4.33, 1.42], 'player_id': [38673, 51713, 50951, 50978, 133498, 33697, 51667, 14736, 735573, 51009, 176224, 735578, 735574, 50983, 51649, 133501, 23418, 795507, 795505, 966120, 285188], 'team': ['home', 'home', 'home', 'away', 'home', 'home', 'home', 'home', 'away', 'away', 'away', 'away', 'away', 'away', 'away', 'home', 'home', 'away', 'away', 'away', 'home'], 'vx': [-56.0
# ...

# %%
data['frames']

# %%
# fetch key moments
import requests

start = 51001  # change as needed
end = 52000  # change as needed
url = f"http://localhost:8000/data/match_key_moments"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)

# %%
# fetch pitch control overlay endpoint
import requests

start = 10  # change as needed
end = 15 # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/pitch_control_overlay?match_id={match_id}&start={start}&end={end}"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
