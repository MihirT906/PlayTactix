# %%
from frame_data_service import FrameDataService
fds = FrameDataService()
frames = fds.get_frames(match_id=1886347, start=311, end=664)
# Out:
# min_frame: 311
# max_frame: 363

# %%
# from data_ingestor_csv import DataIngestor
# data_ingestor = DataIngestor()
# data = data_ingestor.get_frame_data(10)
# import pandas as pd
# pd.set_option('display.max_columns', None)
# data.dtypes

# %%
# match endpoint
import requests

start = 10  # change as needed
end = 20  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/match_meta"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'id': 1886347, 'home_team_score': 2, 'away_team_score': 0, 'date_time': '2024-11-30T04:00:00Z', 'stadium': {'id': 3811, 'name': 'Mount Smart Stadium', 'city': 'Auckland', 'capacity': 25000}, 'home_team': {'id': 4177, 'name': 'Auckland FC', 'short_name': 'Auckland FC', 'acronym': 'AUC'}, 'home_team_kit': {'id': 14025, 'team_id': 4177, 'season': {'id': 95, 'start_year': 2024, 'end_year': 2025, 'name': '2024/2025'}, 'name': 'Home', 'jersey_color': '#2800f0', 'number_color': '#ffffff'}, 'away_team': {'id': 1805, 'name': 'Newcastle United Jets FC', 'short_name': 'Newcastle', 'acronym': 'NEW'}, 'away_team_kit': {'id': 10376, 'team_id': 1805, 'season': {'id': 29, 'start_year': 2024, 'end_year': 2024, 'name': '2024'}, 'name': 'away', 'jersey_color': '#ffffff', 'number_color': '#000000'}, 'home_team_coach': None, 'away_team_coach': None, 'home_team_playing_time': {'minutes_tip': 31.13, 'minutes_otip': 22.2}, 'away_team_playing_time': {'minutes_tip': 22.2, 'minutes_otip': 31.13}, 'competition_edition': {'id': 870, 'competition': {'id': 61, 'area': 'AUS', 'name': 'A-League', 'gender': 'male', 'age_group': 'adult'}, 'season': {'id': 95, 'start_year': 2024, 'end_year': 2025, 'name': '2024/2025'}, 'name': 'AUS - A-League - 2024/2025'}, 'match_periods': [{'period': 1, 'name': 'period_1', 'start_frame': 10, 'end_frame': 27790, 'duration_frames': 27780, 'duration_minutes': 46.3}, {'period': 2, 'name': 'period_2', 'start_frame': 27800, 'end_frame': 59060, 'duration_frames': 31260, 'duration_minutes': 52.1}], 'competition_round': {'id': 611, 'name': 'Round 6', 'round_number': 6, 'potential_overtime': False}, 'referees': [], 'players': [{'player_role': {'id': 15, 'position_group': 'Center Forward', 'name': 'Center Forward', 'acronym': 'CF'}, 'start_time': '00:00:00', 'end_time': '01:25:21', 'number': 10, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 29.55, 'minutes_otip': 18.76, 'start_frame': 10, 'end_frame': 52009, 'minutes_played': 86.65, 'minutes_played_regular_time': 86.65}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 27790, 'minutes_played': 46.3}, {'name': 'period_2', 'minutes_tip': 11.34, 'minutes_otip': 7.73, 'start_frame': 27800, 'end_frame': 52009, 'minutes_played': 40.35}]}, 'team_player_id': 1507965, 'team_id': 4177, 'id': 38673, 'first_name': 'Guillermo Luis', 'last_name': 'May Bartesaghi', 'short_name': 'G. May', 'birthday': '1998-03-11', 'trackable_object': 39794, 'gender': 'male'}, {'player_role': {'id': 20, 'position_group': 'Full Back', 'name': 'Right Back', 'acronym': 'RB'}, 'start_time': '00:00:00', 'end_time': None, 'number': 17, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 31.13, 'minutes_otip': 22.2, 'start_frame': 10, 'end_frame': 59059, 'minutes_played': 98.4, 'minutes_played_regular_time': 98.4}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 27790, 'minutes_played': 46.3}, {'name': 'period_2', 'minutes_tip': 12.92, 'minutes_otip': 11.18, 'start_frame': 27800, 'end_frame': 59059, 'minutes_played': 52.1}]}, 'team_player_id': 1507968, 'team_id': 4177, 'id': 51713, 'first_name': 'Callan', 'last_name': 'Elliot', 'short_name': 'C. Elliott', 'birthday': '1999-07-07', 'trackable_object': 52839, 'gender': 'male'}, {'player_role': {'id': 15, 'position_group': 'Center Forward', 'name': 'Center Forward', 'acronym': 'CF'}, 'start_time': '00:00:00', 'end_time': '01:16:37', 'number': 22, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 26.28, 'minutes_otip': 17.94, 'start_frame': 10, 'end_frame': 46769, 'minutes_played': 77.91, 'minutes_played_regular_time': 77.91}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 2 ...

# %%
import requests

start = 10  # change as needed
end = 100  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1899585  # change as needed
url = f"http://localhost:8000/data/match/{match_id}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'message': 'Data for match 1899585 has been saved to gold_tracking_data.json'}

# %%
# fetch chunk endpoint
import requests

start = 100  # change as needed
end = 600  # change as needed
url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'requested_start': 100, 'requested_end': 600, 'frames': {'100': {'period': 1.0, 'players': {'x': [-40.96, -17.01, -16.16, -23.08, 12.53, 3.57, -7.68, 5.69, 12.45, 18.62, -4.06, 41.19, 17.2, 15.27, 17.52, 13.9, 5.2, 5.26, 2.05, 4.09, -17.24, -6.79], 'y': [2.85, 21.54, -9.81, 1.29, -21.9, 31.43, 16.09, -12.62, 3.43, 22.55, 9.93, 1.89, 10.61, 2.39, 20.05, -7.45, 1.81, 12.72, 19.64, -9.7, 14.77, 12.72], 'player_id': [34718, 698137, 799092, 42510, 51017, 51028, 51015, 51046, 23909, 26969, 27003, 285188, 51667, 33697, 4322, 133498, 23418, 14736, 133501, 965685, 38673, 50951], 'id': [34718, 698137, 799092, 42510, 51017, 51028, 51015, 51046, 23909, 26969, 27003, 285188, 51667, 33697, 4322, 133498, 23418, 14736, 133501, 965685, 38673, 50951], 'short_name': ['J. Oluwayemi', 'I. Hughes', 'M. Sheridan', 'S. Wootton', 'T. Payne', 'S. Sutton', 'A. Rufer', 'P. Retre', 'K. Barbarouses', 'H. Ishige', 'K. Nagasawa', 'A. Paulsen', 'D. Hall', 'N. Pijnaker', 'H. Sakai', 'F. De Vries', 'F. Gallegos', 'L. Verstraete', 'L. Rogerson', 'L. Gillion', 'G. May', 'J. Brimmer'], 'number': [1, 15, 27, 4, 6, 19, 14, 8, 7, 9, 25, 12, 23, 4, 2, 15, 28, 6, 27, 14, 10, 22], 'team_id': [867, 867, 867, 867, 867, 867, 867, 867, 867, 867, 867, 4177, 4177, 4177, 4177, 4177, 4177, 4177, 4177, 4177, 4177, 4177], 'total_time': [5400, 5400, 5400, 5400, 3610, 5677, 5400, 3610, 5400, 5400, 4785, 5400, 5400, 5400, 5400, 5400, 5400, 1301, 3484, 3484, 5400, 4111], 'player_role.name': ['Goalkeeper', 'Center Back', 'Right Center Back', 'Left Center Back', 'Right Wing Back', 'Left Wing Back', 'Left Midfield', 'Right Midfield', 'Right Forward', 'Left Forward', 'Center Forward', 'Goalkeeper', 'Right Center Back', 'Left Center Back', 'Right Back', 'Left Back', 'Left Midfield', 'Right Midfield', 'Right Winger', 'Left Winger', 'Center Forward', 'Center Forward'], 'player_role.acronym': ['GK', 'CB', 'RCB', 'LCB', 'RWB', 'LWB', 'LM', 'RM', 'RF', 'LF', 'CF', 'GK', 'RCB', 'LCB', 'RB', 'LB', 'LM', 'RM', 'RW', 'LW', 'CF', 'CF'], 'is_gk': [True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False], 'direction_player_1st_half': ['left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left'], 'direction_player_2nd_half': ['right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right']}, 'ball': {'ball_x': -7.36, 'ball_y': 15.36, 'ball_z': 0.13}, 'events': []}, '101': {'period': 1.0, 'players': {'x': [-40.9, -16.76, -15.98, -22.93, 12.7, 3.48, -7.51, 5.64, 12.62, 19.07, -3.71, 41.25, 17.43, 15.55, 17.81, 14.11, 5.34, 5.43, 2.3, 4.37, -17.0, -6.49], 'y': [2.91, 21.85, -9.6, 1.33, -21.35, 31.52, 16.34, -12.44, 3.7, 22.75, 9.97, 1.94, 10.72, 2.61, 19.99, -7.23, 2.09, 13.04, 19.91, -9.54, 14.93, 13.1], 'player_id': [34718, 698137, 799092, 42510, 51017, 51028, 51015, 51046, 23909, 26969, 27003, 285188, 51667, 33697, 4322, 133498, 23418, 14736, 133501, 965685, 38673, 50951], 'id': [34718, 698137, 799092, 42510, 51017, 51028, 51015, 51046, 23909, 26969, 27003, 285188, 51667, 33697, 4322, 133498, 23418, 14736, 133501, 965685, 38673, 50951], 'short_name': ['J. Oluwayemi', 'I. Hughes', 'M. Sheridan', 'S. Wootton', 'T. Payne', 'S. Sutton', 'A. Rufer', 'P. Retre', 'K. Barbarouses', 'H. Ishige', 'K. Nagasawa', 'A. Paulsen', 'D. Hall', 'N. Pijnaker', 'H. Sakai', 'F. De Vries', 'F. Gallegos', 'L. ...

# %%
# fetch key moments
import requests

start = 51001  # change as needed
end = 52000  # change as needed
url = f"http://localhost:8000/data/match_key_moments"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'goals': [{'Sequence_ID': 1.0, 'frame_start': 44350, 'frame_end': 44410, 'lead_to_goal': True, 'player_name': 'N. Pijnaker', 'time_end': '69:21.0'}, {'Sequence_ID': 2.0, 'frame_start': 51819, 'frame_end': 51929, 'lead_to_goal': True, 'player_name': 'K. Barbarouses', 'time_end': '81:52.9'}], 'shots': [{'Sequence_ID': 1.0, 'frame_start': 2164, 'frame_end': 2242, 'lead_to_shot': True, 'player_name': 'N. Pijnaker', 'time_end': '03:40.2'}, {'Sequence_ID': 2.0, 'frame_start': 9403, 'frame_end': 9513, 'lead_to_shot': True, 'player_name': 'F. Gallegos', 'time_end': '15:47.3'}, {'Sequence_ID': 3.0, 'frame_start': 10404, 'frame_end': 10468, 'lead_to_shot': True, 'player_name': 'F. Gallegos', 'time_end': '17:22.8'}, {'Sequence_ID': 4.0, 'frame_start': 11313, 'frame_end': 11461, 'lead_to_shot': True, 'player_name': 'L. Verstraete', 'time_end': '19:02.1'}, {'Sequence_ID': 5.0, 'frame_start': 13530, 'frame_end': 13619, 'lead_to_shot': True, 'player_name': 'L. Rogerson', 'time_end': '22:37.9'}, {'Sequence_ID': 6.0, 'frame_start': 23129, 'frame_end': 23288, 'lead_to_shot': True, 'player_name': 'F. Gallegos', 'time_end': '38:44.8'}, {'Sequence_ID': 7.0, 'frame_start': 24891, 'frame_end': 25045, 'lead_to_shot': True, 'player_name': 'M. Sheridan', 'time_end': '41:40.5'}, {'Sequence_ID': 8.0, 'frame_start': 25005, 'frame_end': 25089, 'lead_to_shot': True, 'player_name': 'A. Rufer', 'time_end': '41:44.9'}, {'Sequence_ID': 9.0, 'frame_start': 25461, 'frame_end': 25593, 'lead_to_shot': True, 'player_name': 'H. Sakai', 'time_end': '42:35.3'}, {'Sequence_ID': 10.0, 'frame_start': 26576, 'frame_end': 26723, 'lead_to_shot': True, 'player_name': 'J. Brimmer', 'time_end': '44:28.3'}, {'Sequence_ID': 11.0, 'frame_start': 27113, 'frame_end': 27331, 'lead_to_shot': True, 'player_name': 'J. Brimmer', 'time_end': '45:29.1'}, {'Sequence_ID': 12.0, 'frame_start': 27605, 'frame_end': 27785, 'lead_to_shot': True, 'player_name': 'G. May', 'time_end': '46:14.5'}, {'Sequence_ID': 13.0, 'frame_start': 31198, 'frame_end': 31362, 'lead_to_shot': True, 'player_name': 'H. Ishige', 'time_end': '47:36.2'}, {'Sequence_ID': 14.0, 'frame_start': 40060, 'frame_end': 40145, 'lead_to_shot': True, 'player_name': 'C. Howieson', 'time_end': '62:14.5'}, {'Sequence_ID': 15.0, 'frame_start': 43007, 'frame_end': 43205, 'lead_to_shot': True, 'player_name': 'N. Moreno', 'time_end': '67:20.5'}, {'Sequence_ID': 16.0, 'frame_start': 44350, 'frame_end': 44410, 'lead_to_shot': True, 'player_name': 'N. Pijnaker', 'time_end': '69:21.0'}, {'Sequence_ID': 17.0, 'frame_start': 46367, 'frame_end': 46519, 'lead_to_shot': True, 'player_name': 'S. Sutton', 'time_end': '72:51.9'}, {'Sequence_ID': 18.0, 'frame_start': 51819, 'frame_end': 51929, 'lead_to_shot': True, 'player_name': 'K. Barbarouses', 'time_end': '81:52.9'}, {'Sequence_ID': 19.0, 'frame_start': 54212, 'frame_end': 54398, 'lead_to_shot': True, 'player_name': 'G. May', 'time_end': '85:59.8'}, {'Sequence_ID': 20.0, 'frame_start': 55858, 'frame_end': 56057, 'lead_to_shot': True, 'player_name': 'L. Toomey', 'time_end': '88:45.7'}, {'Sequence_ID': 21.0, 'frame_start': 58100, 'frame_end': 58293, 'lead_to_shot': True, 'player_name': 'C. Howieson', 'time_end': '92:29.3'}, {'Sequence_ID': 22.0, 'frame_start': 59746, 'frame_end': 59892, 'lead_to_shot': True, 'player_name': 'N. Moreno', 'time_end': '95:09.2'}]}
