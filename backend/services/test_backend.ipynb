# %%
# from data_ingestor_csv import DataIngestor
# data_ingestor = DataIngestor()
# data = data_ingestor.get_frame_data(10)
# import pandas as pd
# pd.set_option('display.max_columns', None)
# data.dtypes

# %%
import requests

start = 10  # change as needed
end = 20  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/match_meta"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'id': 1886347, 'home_team_score': 2, 'away_team_score': 0, 'date_time': '2024-11-30T04:00:00Z', 'stadium': {'id': 3811, 'name': 'Mount Smart Stadium', 'city': 'Auckland', 'capacity': 25000}, 'home_team': {'id': 4177, 'name': 'Auckland FC', 'short_name': 'Auckland FC', 'acronym': 'AUC'}, 'home_team_kit': {'id': 14025, 'team_id': 4177, 'season': {'id': 95, 'start_year': 2024, 'end_year': 2025, 'name': '2024/2025'}, 'name': 'Home', 'jersey_color': '#2800f0', 'number_color': '#ffffff'}, 'away_team': {'id': 1805, 'name': 'Newcastle United Jets FC', 'short_name': 'Newcastle', 'acronym': 'NEW'}, 'away_team_kit': {'id': 10376, 'team_id': 1805, 'season': {'id': 29, 'start_year': 2024, 'end_year': 2024, 'name': '2024'}, 'name': 'away', 'jersey_color': '#ffffff', 'number_color': '#000000'}, 'home_team_coach': None, 'away_team_coach': None, 'home_team_playing_time': {'minutes_tip': 31.13, 'minutes_otip': 22.2}, 'away_team_playing_time': {'minutes_tip': 22.2, 'minutes_otip': 31.13}, 'competition_edition': {'id': 870, 'competition': {'id': 61, 'area': 'AUS', 'name': 'A-League', 'gender': 'male', 'age_group': 'adult'}, 'season': {'id': 95, 'start_year': 2024, 'end_year': 2025, 'name': '2024/2025'}, 'name': 'AUS - A-League - 2024/2025'}, 'match_periods': [{'period': 1, 'name': 'period_1', 'start_frame': 10, 'end_frame': 27790, 'duration_frames': 27780, 'duration_minutes': 46.3}, {'period': 2, 'name': 'period_2', 'start_frame': 27800, 'end_frame': 59060, 'duration_frames': 31260, 'duration_minutes': 52.1}], 'competition_round': {'id': 611, 'name': 'Round 6', 'round_number': 6, 'potential_overtime': False}, 'referees': [], 'players': [{'player_role': {'id': 15, 'position_group': 'Center Forward', 'name': 'Center Forward', 'acronym': 'CF'}, 'start_time': '00:00:00', 'end_time': '01:25:21', 'number': 10, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 29.55, 'minutes_otip': 18.76, 'start_frame': 10, 'end_frame': 52009, 'minutes_played': 86.65, 'minutes_played_regular_time': 86.65}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 27790, 'minutes_played': 46.3}, {'name': 'period_2', 'minutes_tip': 11.34, 'minutes_otip': 7.73, 'start_frame': 27800, 'end_frame': 52009, 'minutes_played': 40.35}]}, 'team_player_id': 1507965, 'team_id': 4177, 'id': 38673, 'first_name': 'Guillermo Luis', 'last_name': 'May Bartesaghi', 'short_name': 'G. May', 'birthday': '1998-03-11', 'trackable_object': 39794, 'gender': 'male'}, {'player_role': {'id': 20, 'position_group': 'Full Back', 'name': 'Right Back', 'acronym': 'RB'}, 'start_time': '00:00:00', 'end_time': None, 'number': 17, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 31.13, 'minutes_otip': 22.2, 'start_frame': 10, 'end_frame': 59059, 'minutes_played': 98.4, 'minutes_played_regular_time': 98.4}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 27790, 'minutes_played': 46.3}, {'name': 'period_2', 'minutes_tip': 12.92, 'minutes_otip': 11.18, 'start_frame': 27800, 'end_frame': 59059, 'minutes_played': 52.1}]}, 'team_player_id': 1507968, 'team_id': 4177, 'id': 51713, 'first_name': 'Callan', 'last_name': 'Elliot', 'short_name': 'C. Elliott', 'birthday': '1999-07-07', 'trackable_object': 52839, 'gender': 'male'}, {'player_role': {'id': 15, 'position_group': 'Center Forward', 'name': 'Center Forward', 'acronym': 'CF'}, 'start_time': '00:00:00', 'end_time': '01:16:37', 'number': 22, 'yellow_card': 0, 'red_card': 0, 'injured': False, 'goal': 0, 'own_goal': 0, 'playing_time': {'total': {'minutes_tip': 26.28, 'minutes_otip': 17.94, 'start_frame': 10, 'end_frame': 46769, 'minutes_played': 77.91, 'minutes_played_regular_time': 77.91}, 'by_period': [{'name': 'period_1', 'minutes_tip': 18.21, 'minutes_otip': 11.03, 'start_frame': 10, 'end_frame': 2 ...

# %%
import requests

start = 10  # change as needed
end = 20  # change as needed
# url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
match_id = 1886347  # change as needed
url = f"http://localhost:8000/data/match/{match_id}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'message': 'Data for match 1886347 already exists in gold_tracking_data.json'}

# %%
import requests

start = 100  # change as needed
end = 120  # change as needed
url = f"http://localhost:8000/data/frames?start={start}&end={end}"
frame_number = 10  # change as needed
# url = f"http://localhost:8000/data/frame/{frame_number}"
try:
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Frame data:", data)
    elif response.status_code == 404:
        print("No data found for this frame")
    else:
        print(f"Error {response.status_code}: {response.text}")

except requests.exceptions.RequestException as e:
    print("Request failed:", e)
# Out:
# Frame data: {'100': {'period': 1.0, 'players': {'x': [-40.62, -18.69, -15.96, -17.19, -14.98, -7.4, -9.14, -6.8, -3.53, -5.6, 1.55, 31.26, 14.09, 12.56, 5.83, 6.44, 0.01, 8.6, 1.26, -0.18, -0.24, -1.36], 'y': [-1.01, -10.86, 0.75, -20.85, 13.48, -4.3, 3.43, -13.25, -18.88, 9.17, 8.42, -0.49, 7.11, -2.8, 8.5, -16.99, -0.2, 4.11, -14.97, 6.66, -30.11, -11.61], 'player_id': [931987, 51644, 998256, 795547, 51000, 28293, 133852, 51045, 18573, 25534, 17231, 809070, 26766, 809759, 51005, 973078, 560893, 50949, 50959, 42513, 51646, 51686], 'id': [931987, 51644, 998256, 795547, 51000, 28293, 133852, 51045, 18573, 25534, 17231, 809070, 26766, 809759, 51005, 973078, 560893, 50949, 50959, 42513, 51646, 51686], 'short_name': ['H. Devenish-Meares', 'R. Grant', 'K. Shaw', 'Z. de Jesus', 'J. Courtney-Perkins', 'Léo Sena', 'C. Hollman', 'A. Cáceres', 'J. Lolley', 'A. Ouahim', 'P. Klimala', 'E. Cox', 'B. Vriends', 'P. Kikianis', 'D. Pierias', 'F. Talladira', 'E. Alagich', 'J. Barnett', 'S. Mauk', 'Z. Clough', 'J. Yull', 'A. Goodwin'], 'number': [12, 23, 42, 21, 4, 15, 6, 17, 10, 8, 9, 40, 3, 51, 20, 62, 55, 14, 6, 10, 12, 26], 'team_id': [869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 866, 866, 866, 866, 866, 866, 866, 866, 866, 866, 866], 'total_time': [5400, 5400, 5400, 4067, 5400, 5400, 5400, 5400, 5400, 4605, 4903, 5400, 5400, 5400, 5400, 5400, 5400, 3538, 4246, 5081, 5081, 3538], 'player_role.name': ['Goalkeeper', 'Right Center Back', 'Left Center Back', 'Right Back', 'Left Back', 'Left Defensive Midfield', 'Right Defensive Midfield', 'Attacking Midfield', 'Right Winger', 'Left Winger', 'Center Forward', 'Goalkeeper', 'Right Center Back', 'Left Center Back', 'Right Back', 'Left Back', 'Left Defensive Midfield', 'Right Defensive Midfield', 'Attacking Midfield', 'Right Winger', 'Left Winger', 'Center Forward'], 'player_role.acronym': ['GK', 'RCB', 'LCB', 'RB', 'LB', 'LDM', 'RDM', 'AM', 'RW', 'LW', 'CF', 'GK', 'RCB', 'LCB', 'RB', 'LB', 'LDM', 'RDM', 'AM', 'RW', 'LW', 'CF'], 'is_gk': [True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False], 'direction_player_1st_half': ['left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left'], 'direction_player_2nd_half': ['right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'right_to_left', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right', 'left_to_right']}, 'ball': {'ball_x': 8.26, 'ball_y': -0.24, 'ball_z': 0.29}}, '101': {'period': 1.0, 'players': {'x': [-40.59, -18.7, -15.89, -17.18, -14.84, -7.32, -9.13, -6.84, -3.52, -5.51, 1.86, 31.09, 14.17, 12.57, 5.89, 6.35, 0.02, 8.6, 1.15, -0.36, -0.4, -1.72], 'y': [-1.02, -10.86, 0.77, -20.84, 13.47, -4.28, 3.35, -13.26, -18.9, 9.06, 8.26, -0.5, 7.05, -2.73, 8.42, -17.04, -0.26, 4.13, -14.95, 6.43, -30.04, -11.67], 'player_id': [931987, 51644, 998256, 795547, 51000, 28293, 133852, 51045, 18573, 25534, 17231, 809070, 26766, 809759, 51005, 973078, 560893, 50949, 50959, 42513, 51646, 51686], 'id': [931987, 51644, 998256, 795547, 51000, 28293, 133852, 51045, 18573, 25534, 17231, 809070, 26766, 809759, 51005, 973078, 560893, 50949, 50959, 42513, 51646, 51686], 'short_name': ['H. Devenish-Meares', 'R. Grant', 'K. Shaw', 'Z. de Jesus', 'J. Courtney-Perkins', 'Léo Sena', 'C. Hollman', 'A. Cáceres', 'J. Lolley', 'A. Ouahim', 'P. Klimala', 'E. Cox', 'B. Vriends', 'P. Kikianis', 'D. Pierias', 'F. Talladira', 'E. Alagich', 'J. Ba ...

# %%
data['100']
# Out:
# {'period': 1.0,
#  'players': {'x': [-40.62,
#    -18.69,
#    -15.96,
#    -17.19,
#    -14.98,
#    -7.4,
#    -9.14,
#    -6.8,
#    -3.53,
#    -5.6,
#    1.55,
#    31.26,
#    14.09,
#    12.56,
#    5.83,
#    6.44,
#    0.01,
#    8.6,
#    1.26,
#    -0.18,
#    -0.24,
#    -1.36],
#   'y': [-1.01,
#    -10.86,
#    0.75,
#    -20.85,
#    13.48,
#    -4.3,
#    3.43,
#    -13.25,
#    -18.88,
#    9.17,
#    8.42,
#    -0.49,
#    7.11,
#    -2.8,
#    8.5,
#    -16.99,
#    -0.2,
#    4.11,
#    -14.97,
#    6.66,
#    -30.11,
#    -11.61],
#   'player_id': [931987,
#    51644,
#    998256,
#    795547,
#    51000,
#    28293,
#    133852,
#    51045,
#    18573,
#    25534,
#    17231,
#    809070,
#    26766,
#    809759,
#    51005,
#    973078,
#    560893,
#    50949,
#    50959,
#    42513,
#    51646,
#    51686],
#   'id': [931987,
#    51644,
#    998256,
#    795547,
#    51000,
#    28293,
#    133852,
#    51045,
#    18573,
#    25534,
#    17231,
#    809070,
#    26766,
#    809759,
#    51005,
#    973078,
#    560893,
#    50949,
#    50959,
#    42513,
#    51646,
#    51686],
#   'short_name': ['H. Devenish-Meares',
#    'R. Grant',
#    'K. Shaw',
#    'Z. de Jesus',
#    'J. Courtney-Perkins',
#    'Léo Sena',
#    'C. Hollman',
#    'A. Cáceres',
#    'J. Lolley',
#    'A. Ouahim',
#    'P. Klimala',
#    'E. Cox',
#    'B. Vriends',
#    'P. Kikianis',
#    'D. Pierias',
#    'F. Talladira',
#    'E. Alagich',
#    'J. Barnett',
#    'S. Mauk',
#    'Z. Clough',
#    'J. Yull',
#    'A. Goodwin'],
#   'number': [12,
#    23,
#    42,
#    21,
#    4,
#    15,
#    6,
#    17,
#    10,
#    8,
#    9,
#    40,
#    3,
#    51,
#    20,
#    62,
#    55,
#    14,
#    6,
#    10,
#    12,
#    26],
#   'team_id': [869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    869,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866,
#    866],
#   'total_time': [5400,
#    5400,
#    5400,
#    4067,
#    5400,
#    5400,
#    5400,
#    5400,
#    5400,
#    4605,
#    4903,
#    5400,
#    5400,
#    5400,
#    5400,
#    5400,
#    5400,
#    3538,
#    4246,
#    5081,
#    5081,
#    3538],
#   'player_role.name': ['Goalkeeper',
#    'Right Center Back',
#    'Left Center Back',
#    'Right Back',
#    'Left Back',
#    'Left Defensive Midfield',
#    'Right Defensive Midfield',
#    'Attacking Midfield',
#    'Right Winger',
#    'Left Winger',
#    'Center Forward',
#    'Goalkeeper',
#    'Right Center Back',
#    'Left Center Back',
#    'Right Back',
#    'Left Back',
#    'Left Defensive Midfield',
#    'Right Defensive Midfield',
#    'Attacking Midfield',
#    'Right Winger',
#    'Left Winger',
#    'Center Forward'],
#   'player_role.acronym': ['GK',
#    'RCB',
#    'LCB',
#    'RB',
#    'LB',
#    'LDM',
#    'RDM',
#    'AM',
#    'RW',
#    'LW',
#    'CF',
#    'GK',
#    'RCB',
#    'LCB',
#    'RB',
#    'LB',
#    'LDM',
#    'RDM',
#    'AM',
#    'RW',
#    'LW',
#    'CF'],
#   'is_gk': [True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   'direction_player_1st_half': ['left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left'],
#   'direction_player_2nd_half': ['right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'right_to_left',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right',
#    'left_to_right']},
#  'ball': {'ball_x': 8.26, 'ball_y': -0.24, 'ball_z': 0.29}}

# %%
import numpy as np

# %%
df = pd.read_csv("../../data/match_1886347_enriched_tracking_data.csv")
import numpy as np

df = df.replace([np.inf, -np.inf], np.nan).fillna(0)
# Out:
# /var/folders/5y/nm55z3vs3q72_gcmp1j45hmr0000gn/T/ipykernel_48960/310369593.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/match_1886347_enriched_tracking_data.csv")

# %%
df[df['frame'] == 10]
# Out:
# x                             float64
# y                             float64
# player_id                       int64
# is_detected                      bool
# frame                           int64
# timestamp                      object
# period                        float64
# possession_player_id          float64
# possession_group               object
# ball_x                        float64
# ball_y                        float64
# ball_z                        float64
# is_detected_ball                 bool
# match_id                        int64
# start_time                     object
# end_time                       object
# match_name                     object
# date_time                      object
# home_team.name                 object
# away_team.name                 object
# id                              int64
# short_name                     object
# number                          int64
# team_id                         int64
# team_name                      object
# player_role.position_group     object
# total_time                      int64
# player_role.name               object
# player_role.acronym            object
# is_gk                            bool
# direction_player_1st_half      object
# direction_player_2nd_half      object
# dtype: object
